# %% [markdown]
# [Home](../../README.md)
#
# ### Feature Engineering
#
# This Jupyter Notepad is a selection of data engineering processes you can apply to your data before model training to maximise the performance of your machine learning model. For this demonstration we will engineer new or improved features for the diabetes data you previously wrangled.
#
# #### Feature Engineering Process
# - Deriving new variables from existing ones
#     - Encoding categorical features
#     - Calculating new features from existing features
# - Combining features/feature interactions
# - Identifying the most relevant features for the model
# - Transforming Features
#   - [Dividing Data into categories](https://web.ma.utexas.edu/users/mks/statmistakes/dividingcontinuousintocategories.html)
#   - Mathematical transformations (for example logarithmic transformations). Logarithmic transformations are a powerful tool in the world of statistical analysis. They are often used to transform data that exhibit skewness or other irregularities, making it easier to analyze, visualize, and interpret the results.
# - Creating Domain-Specific Features that incorporating knowledge from the specific domain to create features that capture important characteristics of the data.

# %% [markdown]
# #### Load the required dependencies

# %%
# Import frameworks
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ####  Store the data as a local variable
#
# The data frame is a Pandas object that structures your tabular data into an appropriate format. It loads the complete data in memory so it is now ready for preprocessing.

# %%
data_frame = pd.read_csv("2.2.1.wrangled_data.csv")

# %% [markdown]
# ####  Deriving new variables from existing ones

# %% [markdown]
# ##### Encoding categorical variables
#
# Data Encoding converts textual data into numerical format, so that it can be used as input for algorithms to process. The reason for encoding is that most machine learning algorithms work with numbers and not with text or categorical variables.
#
# To encode the 'SEX' column you will assigning a number value to the gender. Because the data set only provides 2 values we will use -1 and 1.

# %%
# Transforming biomes into numerical values
le = LabelEncoder()
le.fit(data_frame["dominant_biome"])

biome_mapping = dict(zip(le.classes_, range(len(le.classes_))))
print("Biome encoding map:")
for biome, number in biome_mapping.items():
    print(f"  {biome} → {number}")

data_frame["dominant_biome"] = le.transform(data_frame["dominant_biome"])
print("\nEncoded column sample:")
print(data_frame["dominant_biome"].head())
# Out:
# Biome encoding map:
#   beach → 0
#   birch_forest → 1
#   dark_forest → 2
#   forest → 3
#   meadow → 4
#   ocean → 5
#   plains → 6
#   river → 7
#   swamp → 8
#   taiga → 9
#   windswept_gravelly_hills → 10
#   windswept_savanna → 11
#
# Encoded column sample:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: dominant_biome, dtype: int64

# %% [markdown]
# ##### Calculating Age
#
# In the context of medical diagnosis of a lifestyle disease a persons date of birth has limited influence on the target. However, their age is highly relevant. So we will convert two dates into a age. You could consider further encoding this into age brackets or scalling the data, don't forget to use [2.1.2.data.records.md](../2.1.Data_Wrangling/2.1.2.data.records.md) to record any scalling or encoding.

# %%
# Not necessary


# # Convert the 'DoB' and 'DoTest' columns to datetime
# data_frame['DoB'] = pd.to_datetime(data_frame['DoB'], format='%d/%m/%Y')
# data_frame['DoT'] = pd.to_datetime(data_frame['DoT'], format='%d/%m/%Y')

# # Calculate the year difference
# data_frame['Age'] = ((data_frame['DoT'] - data_frame['DoB']).dt.days  / 365.25).round()

# # Print the result
# print(data_frame[['DoB', 'DoT', 'Age']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DoB'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Convert the 'DoB' and 'DoTest' columns to datetime
# ----> 2 data_frame['DoB'] = pd.to_datetime(data_frame['DoB'], format='%d/%m/%Y')
#       3 data_frame['DoT'] = pd.to_datetime(data_frame['DoT'], format='%d/%m/%Y')
#       5 # Calculate the year difference
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'DoB'

# %% [markdown]
# #### Combining features/feature interactions
#
# While individual features can be powerful predictors, their interactions often carry even more information. Feature interaction engineering is the process of creating new features that represent the interaction between two or more features.
#
# In this, case some domain knowledge and data analysis have informed you that the BMI and AGE are risk multipliers (the greater the age and the greater the BMI the greater the feature). From this we can  risk value based on the feature interactions.

# %%
# Features aren't very combine-able


# # Calculate the year difference and round to an integer
# data_frame['Age'] = ((data_frame['DoT'] - data_frame['DoB']).dt.days / 365.25).round().astype(int)

# # Create the 'Risk' column
# data_frame['Risk'] = data_frame['BMI'] * data_frame['Age']

# # Calculate the percentage of the maximum risk
# data_frame['Risk%'] = (data_frame['Risk'] / data_frame['Risk'].max()).round(2)

# # Print the result
# print(data_frame[['Age', 'BMI', 'Risk%']])

# %% [markdown]
# #### Transforming Features
#
# Filtering is like applying the where clause in a database. It is widely used and can help when you need to work on a specific subset of your data. For our use case, let us filter the data to only include rows where the 'SEX' is 'Male'. There is no method call for this, we can just use conditional indexing to fulfil our purpose.
#
# In this, case some domain knowledge and data analysis have informed you that there is 'bimodality' in the data and males and females have a different trends.

# %%
# import pandas as pd
# df = pd.read_csv("2.2.1.wrangled_data.csv")
# zero_counts = (df == 0).sum(axis=0)
# zero_summary = pd.DataFrame({"Column": df.columns, "Zero Count": zero_counts.values})
# print(zero_summary.to_string(index=False))

# Was going to filter columns and keep only some based on # of 0 values
# Instead I will need to manually select features based on domain knowledge
# Out:
#                                     Column  Zero Count
#                                    chunk_x         101
#                                    chunk_z         101
#                             dominant_biome           0
#                    minecraft:acacia_leaves       10197
#                       minecraft:acacia_log       10198
#                              minecraft:air           0
#                   minecraft:amethyst_block        9294
#                 minecraft:amethyst_cluster        9849
#                         minecraft:andesite           4
#                           minecraft:azalea        8187
#                    minecraft:azalea_leaves       10154
#                      minecraft:azure_bluet       10078
#                           minecraft:barrel       10087
#                          minecraft:bedrock           0
#                         minecraft:bee_nest       10174
#                        minecraft:beetroots       10198
#                             minecraft:bell       10199
#                     minecraft:big_dripleaf        8781
#                minecraft:big_dripleaf_stem        9082
#                      minecraft:birch_fence       10199
#                     minecraft:birch_leaves        7379
#                        minecraft:birch_log        7806
#                     minecraft:birch_planks       10198
#                       minecraft:birch_slab       10200
#                     minecraft:birch_stairs       10199
#                        minecraft:black_bed       10198
#              minecraft:black_stained_glass       10191
#                    minecraft:blast_furnace       10199
#                         minecraft:blue_bed       10198
#                      minecraft:blue_orchid       10197
#                  minecraft:blue_terracotta       10195
#                       minecraft:bone_block       10144
#                       minecraft:brick_slab       10197
#                     minecraft:brick_stairs       10196
#                           minecraft:bricks       10195
#                        minecraft:brown_bed       10197
#                   minecraft:brown_mushroom        9654
#             minecraft:brown_mushroom_block       10008
#                 minecraft:budding_amethyst        9366
#                             minecraft:bush        9277
#                           minecraft:cactus       10199
#                          minecraft:calcite        9154
#                         minecraft:campfire       10199
#                           minecraft:candle       10149
#                          minecraft:carrots       10196
#                minecraft:cartography_table       10200
#                         minecraft:cauldron       10200
#                         minecraft:cave_air        8042
#                       minecraft:cave_vines        7288
#                 minecraft:cave_vines_plant        7459
#                            minecraft:chest        9859
#               minecraft:chiseled_sandstone       10195
#            minecraft:chiseled_stone_bricks       10199
#                    minecraft:chiseled_tuff       10028
#             minecraft:chiseled_tuff_bricks        9898
#                             minecraft:clay        4630
#                       minecraft:coal_block       10199
#                         minecraft:coal_ore         153
#                      minecraft:coarse_dirt        9991
#                minecraft:cobbled_deepslate       10172
#                      minecraft:cobblestone        9711
#               minecraft:cobblestone_stairs       10190
#                 minecraft:cobblestone_wall       10199
#                           minecraft:cobweb        9062
#                        minecraft:composter       10198
#                     minecraft:copper_block       10197
#                       minecraft:copper_ore           3
#                       minecraft:cornflower       10077
#             minecraft:cracked_stone_bricks       10183
#                   minecraft:crafting_table       10197
#                  minecraft:crying_obsidian       10197
#                         minecraft:cyan_bed       10200
#                  minecraft:cyan_terracotta       10194
#                        minecraft:dandelion        9785
#                    minecraft:dark_oak_door       10200
#                   minecraft:dark_oak_fence       10200
#                  minecraft:dark_oak_leaves        9016
#                     minecraft:dark_oak_log        9074
#                  minecraft:dark_oak_planks       10196
#                    minecraft:dark_oak_slab       10200
#                  minecraft:dark_oak_stairs       10194
#                minecraft:dark_oak_trapdoor       10197
#                  minecraft:dark_prismarine       10187
#                        minecraft:dead_bush       10053
#                    minecraft:decorated_pot       10132
#                        minecraft:deepslate           0
#               minecraft:deepslate_coal_ore        9063
#             minecraft:deepslate_copper_ore        3055
#            minecraft:deepslate_diamond_ore          23
#            minecraft:deepslate_emerald_ore       10192
#               minecraft:deepslate_gold_ore          58
#               minecraft:deepslate_iron_ore          24
#              minecraft:deepslate_lapis_ore         180
#           minecraft:deepslate_redstone_ore           6
#                      minecraft:diamond_ore        8791
#                          minecraft:diorite           3
#                             minecraft:dirt          29
#                        minecraft:dirt_path       10149
#                        minecraft:dispenser       10107
#                  minecraft:dripstone_block        9732
#                      minecraft:emerald_ore       10072
#                         minecraft:farmland       10196
#                             minecraft:fern        9292
#                     minecraft:firefly_bush       10079
#                       minecraft:flower_pot       10165
#                 minecraft:flowering_azalea        8469
#          minecraft:flowering_azalea_leaves       10156
#                          minecraft:furnace       10199
#                       minecraft:glass_pane       10181
#                      minecraft:glow_lichen        2539
#                       minecraft:gold_block       10196
#                         minecraft:gold_ore        4243
#                          minecraft:granite           4
#                      minecraft:grass_block        3452
#                           minecraft:gravel           0
#                         minecraft:gray_bed       10198
#                  minecraft:gray_terracotta       10200
#                     minecraft:green_carpet       10200
#                       minecraft:grindstone       10197
#                    minecraft:hanging_roots       10170
#                        minecraft:hay_block       10199
#                           minecraft:hopper       10121
#               minecraft:infested_deepslate       10044
#                   minecraft:infested_stone       10052
#                        minecraft:iron_bars       10199
#                       minecraft:iron_chain       10031
#                         minecraft:iron_ore           7
#                     minecraft:jungle_fence       10199
#                    minecraft:jungle_planks       10200
#                      minecraft:jungle_slab       10200
#                    minecraft:jungle_stairs       10200
#                             minecraft:kelp        8808
#                       minecraft:kelp_plant        8812
#                           minecraft:ladder       10141
#                        minecraft:lapis_ore         476
#               minecraft:large_amethyst_bud        9872
#                       minecraft:large_fern        9852
#                             minecraft:lava        6096
#                      minecraft:leaf_litter        7141
#                   minecraft:light_blue_bed       10197
#     minecraft:light_blue_glazed_terracotta       10199
#                   minecraft:light_gray_bed       10195
#     minecraft:light_gray_glazed_terracotta       10199
#         minecraft:light_gray_stained_glass       10185
#            minecraft:light_gray_terracotta       10198
#                            minecraft:lilac       10154
#               minecraft:lily_of_the_valley       10155
#                         minecraft:lily_pad       10087
#                         minecraft:lime_bed       10198
#                             minecraft:loom       10198
#                      minecraft:magenta_bed       10200
#                      minecraft:magma_block        8492
#                  minecraft:mangrove_leaves       10199
#                     minecraft:mangrove_log       10199
#                   minecraft:mangrove_roots       10199
#                    minecraft:mangrove_wood       10199
#              minecraft:medium_amethyst_bud        9856
#                       minecraft:moss_block        6910
#                      minecraft:moss_carpet        7794
#                minecraft:mossy_cobblestone        9380
#           minecraft:mossy_stone_brick_slab       10196
#         minecraft:mossy_stone_brick_stairs       10198
#               minecraft:mossy_stone_bricks       10191
#                              minecraft:mud       10197
#                   minecraft:mud_brick_slab       10195
#                 minecraft:mud_brick_stairs       10195
#                   minecraft:mud_brick_wall       10199
#                       minecraft:mud_bricks       10190
#             minecraft:muddy_mangrove_roots       10199
#                    minecraft:mushroom_stem        9838
#                       minecraft:netherrack       10177
#                       minecraft:oak_button       10112
#                         minecraft:oak_door       10187
#                        minecraft:oak_fence        8969
#                   minecraft:oak_fence_gate       10199
#                       minecraft:oak_leaves        7246
#                          minecraft:oak_log        7388
#                       minecraft:oak_planks        8849
#               minecraft:oak_pressure_plate       10187
#                         minecraft:oak_slab       10191
#                       minecraft:oak_stairs       10169
#                     minecraft:oak_trapdoor       10197
#                         minecraft:obsidian       10195
#                       minecraft:orange_bed       10198
#         minecraft:orange_glazed_terracotta       10198
#                minecraft:orange_terracotta       10197
#                      minecraft:oxeye_daisy       10067
#         minecraft:oxidized_copper_trapdoor       10197
#              minecraft:oxidized_cut_copper       10160
#                       minecraft:packed_ice       10180
#                       minecraft:packed_mud       10193
#                            minecraft:peony       10158
#                         minecraft:pink_bed       10199
#                           minecraft:podzol        9824
#                minecraft:pointed_dripstone        9757
#                minecraft:polished_andesite       10199
#                 minecraft:polished_granite       10200
#                    minecraft:polished_tuff        9915
#               minecraft:polished_tuff_slab       10134
#                            minecraft:poppy        9911
#                         minecraft:potatoes       10197
#                 minecraft:potted_dead_bush       10160
#                      minecraft:powder_snow       10187
#                       minecraft:prismarine       10185
#                minecraft:prismarine_bricks       10185
#                          minecraft:pumpkin       10179
#                       minecraft:purple_bed       10192
#                             minecraft:rail        9311
#                 minecraft:raw_copper_block        9722
#                   minecraft:raw_iron_block        9665
#                          minecraft:red_bed       10200
#                       minecraft:red_candle       10131
#                     minecraft:red_concrete       10192
#            minecraft:red_glazed_terracotta       10135
#                     minecraft:red_mushroom       10106
#               minecraft:red_mushroom_block        9817
#                   minecraft:red_terracotta       10192
#                     minecraft:redstone_ore        4903
#                      minecraft:rooted_dirt       10155
#                        minecraft:rose_bush       10158
#                             minecraft:sand        6453
#                        minecraft:sandstone        9515
#                            minecraft:sculk       10095
#                   minecraft:sculk_catalyst       10180
#                     minecraft:sculk_sensor       10169
#                   minecraft:sculk_shrieker       10194
#                       minecraft:sculk_vein       10093
#                      minecraft:sea_lantern       10185
#                         minecraft:seagrass        6351
#                      minecraft:short_grass        2744
#               minecraft:small_amethyst_bud        9839
#                   minecraft:small_dripleaf        9387
#                   minecraft:smithing_table       10200
#                    minecraft:smooth_basalt        8991
#                     minecraft:smooth_stone       10200
#                minecraft:smooth_stone_slab       10198
#                             minecraft:snow       10189
#                          minecraft:spawner        9895
#                    minecraft:spore_blossom        9445
#                      minecraft:spruce_door       10199
#                     minecraft:spruce_fence       10190
#                    minecraft:spruce_leaves        9179
#                       minecraft:spruce_log        9239
#                    minecraft:spruce_planks       10189
#                      minecraft:spruce_slab       10195
#                    minecraft:spruce_stairs       10189
#                  minecraft:spruce_trapdoor       10198
#                            minecraft:stone           0
#                 minecraft:stone_brick_slab       10195
#               minecraft:stone_brick_stairs       10193
#                     minecraft:stone_bricks       10179
#                     minecraft:stone_button       10197
#                       minecraft:stone_slab       10200
#                 minecraft:stripped_oak_log       10194
#                minecraft:stripped_oak_wood       10200
#                       minecraft:sugar_cane       10105
#                minecraft:suspicious_gravel       10179
#                 minecraft:sweet_berry_bush       10164
#                       minecraft:tall_grass        7565
#                    minecraft:tall_seagrass        6462
#                            minecraft:torch       10199
#                    minecraft:trial_spawner       10111
#                         minecraft:tripwire       10198
#                    minecraft:tripwire_hook       10198
#                             minecraft:tuff           3
#                      minecraft:tuff_bricks        9878
#                            minecraft:vault       10078
#                             minecraft:vine        8001
#                       minecraft:wall_torch        9860
#                            minecraft:water        1670
#            minecraft:waxed_chiseled_copper        9985
#               minecraft:waxed_copper_block        9898
#                minecraft:waxed_copper_bulb        9919
#                minecraft:waxed_copper_door       10194
#               minecraft:waxed_copper_grate       10010
#                 minecraft:waxed_cut_copper       10103
#            minecraft:waxed_cut_copper_slab       10093
#          minecraft:waxed_cut_copper_stairs       10179
#        minecraft:waxed_exposed_copper_bulb        9963
#   minecraft:waxed_oxidized_chiseled_copper       10192
#            minecraft:waxed_oxidized_copper        9923
#       minecraft:waxed_oxidized_copper_bulb       10046
#       minecraft:waxed_oxidized_copper_door       10155
#      minecraft:waxed_oxidized_copper_grate       10083
#   minecraft:waxed_oxidized_copper_trapdoor       10162
#        minecraft:waxed_oxidized_cut_copper        9955
#   minecraft:waxed_oxidized_cut_copper_slab       10190
# minecraft:waxed_oxidized_cut_copper_stairs        9962
#      minecraft:waxed_weathered_copper_bulb        9965
#                       minecraft:wet_sponge       10200
#                            minecraft:wheat       10197
#                        minecraft:white_bed       10194
#                     minecraft:white_carpet       10200
#                   minecraft:white_concrete       10194
#              minecraft:white_stained_glass       10189
#                 minecraft:white_terracotta       10184
#                       minecraft:white_wool       10199
#                      minecraft:wildflowers        9199
#                       minecraft:yellow_bed       10191
#                    minecraft:yellow_carpet       10200
#         minecraft:yellow_glazed_terracotta       10200
#                      minecraft:yellow_wool       10199

# %% [markdown]
# #### Creating Domain-Specific Features
#
# Domain knowledge is about understanding the domain or subject area of the data. In This case the domain is 'health' and more specifically   'Epidemiology' which is the study of how often diseases occur in different groups of people and why.
#
# The column called '1st Degree Relatives' is a domain specific feature as is records the number of family members in the individuals direct bloodline who have developed type 2 adult onset diabetes. Domain specific knowledge, is that Family history of disease in first degree relatives is a major risk factor, especially for premature events.
#
# First we will convert convert the FDR value to a risk percentage, because the risk can never be 0 (will never happen) or 100% (will definitely happen) we will scale the result between 0.15 and 0.85.

# %%
# Calculate the family history risk
data_frame['FHRisk'] = (data_frame['FDR'] / data_frame['FDR'].max())

# Scale the result between 0.15 and 0.85
min_val = 0.15
max_val = 0.85
data_frame['FHRisk'] = (((data_frame['FHRisk'] - data_frame['FHRisk'].min()) / (data_frame['FHRisk'].max() - data_frame['FHRisk'].min())) * (max_val - min_val) + min_val).round(2)

# Print the result
print(data_frame[['Age', 'FDR', 'FHRisk']])

# %% [markdown]
# Then to make it even more meaningful, we will combine it with the `Risk` feature we engineered using the `AGE` and `BMI` features to create a combined risk 'interaction feature' that captures real-world relationships between the features.
#
# Again we will scale the result between 0.15 and 0.85.

# %%
data_frame['CombRisk'] = (data_frame['FHRisk'] * data_frame['Risk%']).round(2)

min_val = 0.15
max_val = 0.85
data_frame['CombRisk'] = (((data_frame['CombRisk'] - data_frame['CombRisk'].min()) / (data_frame['CombRisk'].max() - data_frame['CombRisk'].min())) * (max_val - min_val) + min_val).round(2)

# Print the result
print(data_frame[['Age', 'Risk%', 'FHRisk', 'CombRisk']])

# %% [markdown]
# #### Save the wrangled and engineered data to CSV

# %%
data_frame.to_csv('../2.3.Model_Training/2.3.1.model_ready_data.csv', index=False)
